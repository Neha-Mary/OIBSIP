# %% [markdown]
# ![Screenshot 2023-12-19 103925.png](data:image/png;base64,...)

# %% [markdown]
# Completed By: **NEHA MARY THOMAS**

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/car data.csv')

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.dtypes
# Out:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Driven_kms         int64
# Fuel_Type         object
# Selling_type      object
# Transmission      object
# Owner              int64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       299 non-null    object
#  1   Year           299 non-null    int64
#  2   Selling_Price  299 non-null    float64
#  3   Present_Price  299 non-null    float64
#  4   Driven_kms     299 non-null    int64
#  5   Fuel_Type      299 non-null    object
#  6   Selling_type   299 non-null    object
#  7   Transmission   299 non-null    object
#  8   Owner          299 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 23.4+ KB

# %%
corrmat = df.corr()
plt.figure(figsize=(10,10))
g=sns.heatmap(corrmat,annot=True)
# Out:
# <ipython-input-76-3bed5ec1866d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
df['Car_Name'].value_counts()
# Out:
# city                        26
# corolla altis               16
# verna                       14
# brio                        10
# fortuner                    10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: Car_Name, Length: 98, dtype: int64

# %%
df['Fuel_Type'].value_counts()
# Out:
# Petrol    239
# Diesel     58
# CNG         2
# Name: Fuel_Type, dtype: int64

# %%
df['Selling_type'].value_counts()
# Out:
# Dealer        193
# Individual    106
# Name: Selling_type, dtype: int64

# %%
df['Transmission'].value_counts()
# Out:
# Manual       260
# Automatic     39
# Name: Transmission, dtype: int64

# %%
df1=pd.get_dummies(df[['Fuel_Type','Selling_type','Transmission',]],drop_first=True)
df1
# Out:
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Selling_type_Individual  \
# 0                   0                 1                        0
# 1                   1                 0                        0
# 2                   0                 1                        0
# 3                   0                 1                        0
# 4                   1                 0                        0
# ..                ...               ...                      ...
# 296                 1                 0                        0
# 297                 0                 1                        0
# 298                 0                 1                        0
# 299                 1                 0                        0
# 300                 0                 1                        0
#
#      Transmission_Manual
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 296                    1
# 297                    1
# 298                    1
# 299                    1
# 300                    1
#
# [299 rows x 4 columns]

# %%
dfe=pd.concat([df,df1],axis=1)
dfe
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0         Dealer       Manual      0                 0                 1
# 1         Dealer       Manual      0                 1                 0
# 2         Dealer       Manual      0                 0                 1
# 3         Dealer       Manual      0                 0                 1
# 4         Dealer       Manual      0                 1                 0
# ..           ...          ...    ...               ...               ...
# 296       Dealer       Manual      0                 1                 0
# 297       Dealer       Manual      0                 0                 1
# 298       Dealer       Manual      0                 0                 1
# 299       Dealer       Manual      0                 1                 0
# 300       Dealer       Manual      0                 0                 1
#
#      Selling_type_Individual  Transmission_Manual
# 0                          0                    1
# 1                          0                    1
# 2                          0                    1
# 3                          0                    1
# 4                          0                    1
# ..                       ...                  ...
# 296                        0                    1
# 297                        0                    1
# 298                        0                    1
# 299                        0                    1
# 300                        0                    1
#
# [299 rows x 13 columns]

# %%
dfe=dfe.drop(['Car_Name','Fuel_Type','Transmission','Selling_type'],axis=1)
dfe
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Owner  Fuel_Type_Diesel  \
# 0    2014           3.35           5.59       27000      0                 0
# 1    2013           4.75           9.54       43000      0                 1
# 2    2017           7.25           9.85        6900      0                 0
# 3    2011           2.85           4.15        5200      0                 0
# 4    2014           4.60           6.87       42450      0                 1
# ..    ...            ...            ...         ...    ...               ...
# 296  2016           9.50          11.60       33988      0                 1
# 297  2015           4.00           5.90       60000      0                 0
# 298  2009           3.35          11.00       87934      0                 0
# 299  2017          11.50          12.50        9000      0                 1
# 300  2016           5.30           5.90        5464      0                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                   1                        0                    1
# 1                   0                        0                    1
# 2                   1                        0                    1
# 3                   1                        0                    1
# 4                   0                        0                    1
# ..                ...                      ...                  ...
# 296                 0                        0                    1
# 297                 1                        0                    1
# 298                 1                        0                    1
# 299                 0                        0                    1
# 300                 1                        0                    1
#
# [299 rows x 9 columns]

# %%
dfe.columns
# Out:
# Index(['Year', 'Selling_Price', 'Present_Price', 'Driven_kms', 'Owner',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Selling_type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %% [markdown]
# Splitting data into independent and dependent variables

# %%
x=dfe.drop(['Present_Price'],axis=1)

# %%
x
# Out:
#      Year  Selling_Price  Driven_kms  Owner  Fuel_Type_Diesel  \
# 0    2014           3.35       27000      0                 0
# 1    2013           4.75       43000      0                 1
# 2    2017           7.25        6900      0                 0
# 3    2011           2.85        5200      0                 0
# 4    2014           4.60       42450      0                 1
# ..    ...            ...         ...    ...               ...
# 296  2016           9.50       33988      0                 1
# 297  2015           4.00       60000      0                 0
# 298  2009           3.35       87934      0                 0
# 299  2017          11.50        9000      0                 1
# 300  2016           5.30        5464      0                 0
#
#      Fuel_Type_Petrol  Selling_type_Individual  Transmission_Manual
# 0                   1                        0                    1
# 1                   0                        0                    1
# 2                   1                        0                    1
# 3                   1                        0                    1
# 4                   0                        0                    1
# ..                ...                      ...                  ...
# 296                 0                        0                    1
# 297                 1                        0                    1
# 298                 1                        0                    1
# 299                 0                        0                    1
# 300                 1                        0                    1
#
# [299 rows x 8 columns]

# %%
y=dfe['Present_Price']

# %%
y
# Out:
# 0       5.59
# 1       9.54
# 2       9.85
# 3       4.15
# 4       6.87
#        ...
# 296    11.60
# 297     5.90
# 298    11.00
# 299    12.50
# 300     5.90
# Name: Present_Price, Length: 299, dtype: float64

# %% [markdown]
# Splitting data into training data and testing data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %% [markdown]
# ModelCreation

# %% [markdown]
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 1.34500124e+01,  1.14556555e+01, -1.18898742e+00,  1.10278819e+01,
#         1.03148836e+01,  7.39474685e+00,  1.18246804e+01,  2.86783152e-01,
#         1.14181439e+01,  3.67370066e+00,  1.82881577e+01,  2.78570250e+00,
#         8.13264011e-01, -1.37918448e+00,  4.98259210e+00,  6.71252739e+00,
#        -4.78230736e-01,  3.07197498e-01,  5.35215232e+01,  4.27343809e-01,
#         5.19576792e-02,  4.92983209e-01,  6.85008681e+00,  6.56867659e+00,
#         8.17801164e+00,  1.56875435e+01,  1.36349058e+01,  1.25916361e+00,
#         8.42802698e+00,  8.99460018e+00,  5.46316536e+00,  5.46034853e+00,
#         8.15761216e+00,  5.88708109e+00,  5.19262230e+00,  9.06459403e+00,
#         1.05506716e+00,  1.43907566e+01,  9.74611817e-01,  9.49648058e+00,
#         1.05765265e+01,  2.01074923e+01,  2.62677400e-02,  8.59599121e+00,
#         4.12742619e-01,  5.06881884e+00,  1.79217536e+01,  6.75889087e+00,
#         5.86123681e+00,  2.52479989e+00,  5.81129695e-01,  7.24379990e-01,
#         5.74026660e+00,  2.01707250e+01,  1.04973807e+01,  8.05909783e+00,
#         7.03383947e+00,  7.67777735e+00,  1.88868312e+01,  1.23794610e+01,
#         1.02388543e+01,  1.50950178e+00,  1.09052453e+00,  3.75494180e+00,
#         5.59815674e+00,  3.80507910e+00,  1.68044801e+01,  1.04686126e+01,
#         3.55256620e+00,  7.22885663e+00, -1.11044388e+00,  9.95193366e+00,
#         8.86492089e+00,  1.39878577e+01,  2.46732753e+00,  6.03549739e+00,
#         2.50666933e+01,  1.77946852e+01,  9.52288356e+00,  4.52504564e+00,
#         8.39250707e-01,  2.68997141e+00,  2.74046757e-01,  2.31640821e+01,
#         1.89721450e+01, -1.15337969e+00,  5.85140872e+00,  1.09796461e+01,
#         1.48102056e+00, -3.57009001e+00])

# %%
df1=pd.DataFrame({'Actual _value':y_test,'Predicted_value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#      Actual _value  Predicted_value  Difference
# 283          11.80        13.450012   -1.650012
# 267           9.40        11.455655   -2.055655
# 166           0.55        -1.188987    1.738987
# 9             8.92        11.027882   -2.107882
# 78           22.83        10.314884   12.515116
# ..             ...              ...         ...
# 134           0.81        -1.153380    1.963380
# 73            5.71         5.851409   -0.141409
# 15           10.79        10.979646   -0.189646
# 10            3.60         1.481021    2.118979
# 159           0.51        -3.570090    4.080090
#
# [90 rows x 3 columns]

# %%
print("slope is",model.coef_)
# Out:
# slope is [-6.10958357e-01  1.82055869e+00  2.61531812e-05 -1.58382321e+00
#  -2.26122383e+00 -1.15940371e+00  1.11805837e+00  1.84860378e+00]

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# Performance Evaluation

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("Error percentage is ",mean_absolute_percentage_error(y_test,y_pred))
mean_sq_error=mean_squared_error(y_test,y_pred)
print("Mean squared error is ",mean_sq_error)
print("Root Mean Sqaured Error is ",np.sqrt(mean_sq_error))
print('r2 score is',r2_score(y_test,y_pred))
# Out:
# MAE 2.64275708925127
# Error percentage is  1.1271834292186502
# Mean squared error is  19.576217937605605
# Root Mean Sqaured Error is  4.4245019988249075
# r2 score is 0.638641227277772

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
model=DecisionTreeRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([13.6 ,  8.89,  0.54, 10.79, 13.7 ,  5.7 ,  9.4 ,  1.47,  9.4 ,
#         1.05, 18.61,  0.57,  0.65,  0.54,  5.8 ,  7.27,  0.55,  1.47,
#        23.15,  0.84,  0.54,  2.37,  5.7 ,  2.69,  7.49, 13.6 ,  9.4 ,
#         1.47,  9.4 ,  9.9 ,  5.43,  5.8 ,  7.49,  4.6 ,  9.4 ,  9.4 ,
#         1.47,  0.75,  1.5 , 13.74,  9.4 , 13.09,  1.17,  2.69,  0.95,
#         0.75, 14.79,  6.8 ,  9.4 ,  0.58,  0.99,  0.65,  7.98, 20.91,
#         9.4 ,  7.6 ,  6.8 ,  5.35, 13.09, 18.61, 10.  ,  0.75,  0.57,
#         0.99,  4.6 ,  3.98, 13.6 , 12.48,  4.6 ,  9.95,  0.95,  9.4 ,
#         9.94, 13.6 ,  0.95,  4.6 , 35.96, 18.61, 13.74,  0.75,  0.65,
#         4.43,  0.81, 20.91, 13.09,  0.87,  3.98,  9.29,  3.76,  0.51])

# %%
df1=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#      Actual_value  Predicted_value  Difference
# 283         11.80            13.60       -1.80
# 267          9.40             8.89        0.51
# 166          0.55             0.54        0.01
# 9            8.92            10.79       -1.87
# 78          22.83            13.70        9.13
# ..            ...              ...         ...
# 134          0.81             0.87       -0.06
# 73           5.71             3.98        1.73
# 15          10.79             9.29        1.50
# 10           3.60             3.76       -0.16
# 159          0.51             0.51        0.00
#
# [90 rows x 3 columns]

# %% [markdown]
# Performance Evaluation

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("Error percentage is ",mean_absolute_percentage_error(y_test,y_pred))
mean_sq_error=mean_squared_error(y_test,y_pred)
print("Mean squared error is ",mean_sq_error)
print("Root Mean Sqaured Error is ",np.sqrt(mean_sq_error))
print('r2 score is',r2_score(y_test,y_pred))
# Out:
# MAE 1.7344777777777776
# Error percentage is  0.1829655818055457
# Mean squared error is  11.980497188888888
# Root Mean Sqaured Error is  3.461285482142276
# r2 score is 0.7788511665237157

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([11.981  , 10.2837 ,  0.56286, 10.8944 , 12.3881 ,  5.778  ,
#        11.3128 ,  1.7007 , 10.2617 ,  0.94276, 16.9738 ,  0.635  ,
#         0.65097,  0.57332,  6.4827 ,  7.2666 ,  0.7103 ,  1.5338 ,
#        53.8635 ,  0.91726,  0.65786,  2.0095 ,  5.7747 ,  2.5808 ,
#         7.5484 , 12.595  , 12.078  ,  1.688  ,  9.5763 ,  9.5234 ,
#         5.9821 ,  6.9229 ,  7.5589 ,  5.0368 ,  8.0007 ,  9.052  ,
#         1.6168 ,  0.9538 ,  1.6461 , 13.462  , 10.0387 , 13.3509 ,
#         1.4906 ,  2.8796 ,  0.87229,  0.7128 , 13.6416 ,  6.287  ,
#         8.6961 ,  0.7609 ,  0.90966,  0.62187,  9.605  , 21.8003 ,
#         8.6711 ,  9.0241 ,  7.6423 ,  7.5978 , 13.1373 , 16.6932 ,
#         9.726  ,  0.7029 ,  0.6089 ,  1.02402,  5.6797 ,  4.6434 ,
#        13.4698 , 10.7467 ,  4.1846 ,  8.2718 ,  0.9196 , 10.0396 ,
#        10.3561 , 13.3351 ,  0.93091,  5.8867 , 31.4786 , 16.9684 ,
#        12.5248 ,  0.7179 ,  0.63609,  4.4263 ,  0.7383 , 22.6793 ,
#        13.8382 ,  0.8677 ,  5.9521 , 10.0085 ,  4.1976 ,  0.5295 ])

# %%
df1=pd.DataFrame({'Actual_value':y_test,'Predicted_value':y_pred,'Difference':y_test-y_pred})
df1
# Out:
#      Actual_value  Predicted_value  Difference
# 283         11.80         11.98100    -0.18100
# 267          9.40         10.28370    -0.88370
# 166          0.55          0.56286    -0.01286
# 9            8.92         10.89440    -1.97440
# 78          22.83         12.38810    10.44190
# ..            ...              ...         ...
# 134          0.81          0.86770    -0.05770
# 73           5.71          5.95210    -0.24210
# 15          10.79         10.00850     0.78150
# 10           3.60          4.19760    -0.59760
# 159          0.51          0.52950    -0.01950
#
# [90 rows x 3 columns]

# %% [markdown]
# Performance Evaluation

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("Error percentage is ",mean_absolute_percentage_error(y_test,y_pred))
mean_sq_error=mean_squared_error(y_test,y_pred)
print("Mean squared error is ",mean_sq_error)
print("Root Mean Sqaured Error is ",np.sqrt(mean_sq_error))
print('r2 score is',r2_score(y_test,y_pred))
# Out:
# MAE 1.7210936666666687
# Error percentage is  0.18932026834769136
# Mean squared error is  13.025674555232245
# Root Mean Sqaured Error is  3.609109939477079
# r2 score is 0.7595581645974672
